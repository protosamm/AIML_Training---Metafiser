# %%
def Input():
  num1 = int(input("Enter first number: "))
  num2 = int(input("Enter second number: "))
  operator = input("Enter the operator(+,-,*,/): ")

  return num1, num2, operator

# %%
def PerformOperation(num1, num2, operator):
  if(operator == '+'):
    print(f"Addition of {num1} and {num2} is {num1+num2}")
  elif(operator == '-'):
    print(f"Subtraction of {num1} and {num2} is {num1-num2}")
  elif(operator == '*'):
    print(f"Multiplication of {num1} and {num2} is {num1*num2}")
  elif(operator == '/'):
    print(f"Division of {num1} and {num2} is {num1/num2}")
  else:
    print("Wrong operator")

# %%
def ConditionCheck():
  chk = input("Do you want to continue(y/n): ")
  if(chk == 'n' or chk == 'N'):
    return False
  elif(chk == 'y' or chk == 'Y'):
    return True
  else:
    print("Wrong character selected")
    return ConditionCheck()

# %%
flag = True
while(flag != False):
  num1,num2,operator = Input()
  PerformOperation(num1, num2, operator)
  flag = ConditionCheck()
# Out:
# Enter first number: 30
# Enter second number: 20
# Enter the operator(+,-,*,/): +
# Addition of 30 and 20 is 50
# Do you want to continue(y/n): k
# Wrong character selected
# Do you want to continue(y/n): n

# %%
import numpy as np
a = 10
b = 20
c = np.random.randint(a,b,10)
print(c)
# Out:
# [17 12 15 15 15 14 12 14 15 14]

# %%
a = 1+(2-1)*np.random.random((10))
print(a)
# Out:
# [1.38456435 1.97160457 1.72150874 1.53045095 1.16352833 1.25336888
#  1.40184942 1.37402925 1.70051471 1.33754152]
